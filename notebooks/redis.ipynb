# %%
from redis import Redis

r = Redis(
    host='localhost', 
    port=6379, 
    db=0,
    decode_responses=True    
)

# %%
r.set("client", "redis-py")
# Out:
# True

# %%
r.get("client")
# Out:
# 'redis-py'

# %%
r.lpush("tasks", "Task -1")
# Out:
# 5

# %%
r.lrange("tasks", 0, -1)
# Out:
# ['Task -1', 'Task 1', 'Task 2', 'Task 3', 'Task 4']

# %%
r.smembers("tags")
# Out:
# {'python', 'redis'}

# %%
r.hgetall("user:1")
# Out:
# {'name': 'John', 'age': '12', 'city': 'None'}
